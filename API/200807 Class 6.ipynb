# %%
url1 ='http://apis.data.go.kr/6480000/gyeongnamwalklikeroad/gyeongnamwalklikeroadlist?serviceKey='

# %%
url2 ='&numOfRows=10&pageNo=1'

# %%
url3 ='&type=json'

# %%
my_key ='%2Bna8y%2B7XNm7r55Suf5yyGwSnYWea%2BXR68NSdlMPacSIRrLaVZ5%2F8XTV770NMtO8wO6uHBstMaFlgDvestKH7Ug%3D%3D'

# %%
#url = url1 + my_key + url2 + url3
#url
# Out:
# 'http://apis.data.go.kr/6480000/gyeongnamwalklikeroad/gyeongnamwalklikeroadlist?serviceKey=%2Bna8y%2B7XNm7r55Suf5yyGwSnYWea%2BXR68NSdlMPacSIRrLaVZ5%2F8XTV770NMtO8wO6uHBstMaFlgDvestKH7Ug%3D%3D&numOfRows=10&pageNo=1&type=json'

# %%
url = 'http://apis.data.go.kr/6480000/gyeongnamwalklikeroad/gyeongnamwalklikeroadlist?serviceKey=%2Bna8y%2B7XNm7r55Suf5yyGwSnYWea%2BXR68NSdlMPac
SIRrLaVZ5%2F8XTV770NMtO8wO6uHBstMaFlgDvestKH7Ug%3D%3D&numOfRows=10&pageNo=1&type=json'

# %%
import urllib.request
res = urllib.request.urlopen(url); res

# %%
json_str = res.read() ; json_str
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?><response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL_CODE</resultMsg>\n  </header>\n  <body>\n    <items>\n      <item>\n        <insttnm>\xec\xb0\xbd\xec\x9b\x90\xec\x8b\x9c \xeb\xac\xb8\xed\x99\x94\xea\xb4\x80\xea\xb4\x91\xea\xb3\xbc :\xec\x9d\x98\xec\xb0\xbd\xea\xb5\xac \xec\xa4\x91\xec\x95\x99\xeb\x8c\x80\xeb\xa1\x9c 151 T.055-225-3651\n\n\xec\xa7\x84\xed\x95\xb4\xea\xb5\xac\xec\xb2\xad \xeb\xac\xb8\xed\x99\x94\xea\xb4\x80\xea\xb4\x91\xea\xb3\xbc : \xec\xb0\xbd\xec\x9b\x90\xec\x8b\x9c \xec\xa7\x84\xed\x95\xb4\xea\xb5\xac \xed\x92\x8d\xed\x98\xb8\xeb\x8f\x99 1 T.055-548-2433</insttnm>\n        <fileurl2>https://www.gyeongnam.go.kr/upload_data/board_data/BBS_0002006/themegil_0_1479283490.jpg</fileurl2>\n        <category_name1>\xec\xb0\xbd\xec\x9b\x90\xec\x8b\x9c</category_name1>\n        <roadlength>\xec\x95\xbd 16km</roadlength>\n        <courseinfo>\xec\x82\xb0\xea\xb8\xb8\xec\x9d\x84 \xea\xb1\xb8\xec\x9c\xbc\xeb\
# ...

# %%
res = urllib.request.urlopen(url)      ###### 그냥 공백이 나올 경우, res 복붙해서 붙여넣고 하면 됨.
json_str = res.read().decode('utf-8') ; json_str
# Out:
# '<?xml version="1.0" encoding="UTF-8"?><response>\n  <header>\n    <resultCode>00</resultCode>\n    <resultMsg>NORMAL_CODE</resultMsg>\n  </header>\n  <body>\n    <items>\n      <item>\n        <insttnm>창원시 문화관광과 :의창구 중앙대로 151 T.055-225-3651\n\n진해구청 문화관광과 : 창원시 진해구 풍호동 1 T.055-548-2433</insttnm>\n        <fileurl2>https://www.gyeongnam.go.kr/upload_data/board_data/BBS_0002006/themegil_0_1479283490.jpg</fileurl2>\n        <category_name1>창원시</category_name1>\n        <roadlength>약 16km</roadlength>\n        <courseinfo>산길을 걸으면서 바다를 볼 수 있는 곳!진해의 아름다운 천혜의 바다경관이 눈앞에 펼쳐지는 곳! 아름다운숲길에는 새들의 노래소리를 들을수있어 귀가 행복하고, 멀리펼쳐진 아름다운 진해만의 다도해를 조망할수있어 눈이행복하고, 울창한 숲에서 뿜어내는 피톤치드를 온 몸에 담을 수 있어 계속 걷고싶어지는 길이어서 남기는 발자국 갯수만큼 건강수준도 올라가는 코스이다.</courseinfo>\n        <fileurl1>https://www.gyeongnam.go.kr/upload_data/board_data/BBS_0002006/themegil_1_1479285775.jpg</fileurl1>\n        <data_content>&lt;!-- 관광지정보 --&gt;\n\n\t\t\t&lt;h5&gt;관광지정보&lt;/h5&gt;\n\n\t\t\t&lt;div class="edu_detail_txt"&gt;\n\n\t\t\t\t&lt;tab
# ...

# %%
import json

# %%
json_object = json.loads(json_str)  ####문자열을 json 으로 변환
json_object
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-89-ecdc29dc41d5> in <module>
# ----> 1 json_object = json.loads(json_str)  ####문자열을 json 으로 변환
#       2 json_object
#
# C:\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# C:\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
json_object['body']['items']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-87-d4ee962b59e1> in <module>
# ----> 1 json_object['body']['items']
#
# NameError: name 'json_object' is not defined

# %%
body = [json_object['body']['items']]

# %%
df = pd.json_normalize(json_object['body']['items']) ;df
