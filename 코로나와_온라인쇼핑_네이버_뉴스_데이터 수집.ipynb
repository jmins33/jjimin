# %% [markdown]
# ## 네이버뉴스_데이터 수집
# - 참고 : https://bumcrush.tistory.com/155

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

# %%
RESULT_PATH = 'C:/Users/jminw/'
now = datetime.now() #파일이름 현 시간으로 저장하기

# %%
def get_news(n_url):
    news_detail = []

    breq = requests.get(n_url)
    bsoup = BeautifulSoup(breq.content, 'html.parser')

    title = bsoup.select('h3#articleTitle')[0].text  #대괄호는  h3#articleTitle 인 것중 첫번째 그룹만 가져오겠다.
    news_detail.append(title)

    pdate = bsoup.select('.t11')[0].get_text()[:11]
    news_detail.append(pdate)

    _text = bsoup.select('#articleBodyContents')[0].get_text().replace('\n', " ")
    btext = _text.replace("// flash 오류를 우회하기 위한 함수 추가 function _flash_removeCallback() {}", "")
    news_detail.append(btext.strip())
  
    news_detail.append(n_url)
    
    pcompany = bsoup.select('#footer address')[0].a.get_text()
    news_detail.append(pcompany)

    return news_detail

# %%
def crawler(maxpage,query,s_date,e_date):

    s_from = s_date.replace(".","")
    e_to = e_date.replace(".","")
    page = 1
    maxpage_t =(int(maxpage)-1)*10+1   # 11= 2페이지 21=3페이지 31=4페이지  ...81=9페이지 , 91=10페이지, 101=11페이지
    f = open("C:/Users/jminw/contents_text.txt", 'w', encoding='utf-8')
    
    while page < maxpage_t:
    
        print(page)
    
        url = "https://search.naver.com/search.naver?where=news&query=" + query + "&sort=0&ds=" + s_date + "&de=" + e_date + "&nso=so%3Ar%2Cp%3Afrom" + s_from + "to" + e_to + "%2Ca%3A&start=" + str(page)
        
        req = requests.get(url)
        print(url)
        cont = req.content
        soup = BeautifulSoup(cont, 'html.parser')
            #print(soup)
    
        for urls in soup.select("._sp_each_url"):
            try :
                #print(urls["href"])
                if urls["href"].startswith("https://news.naver.com"):
                    #print(urls["href"])
                    news_detail = get_news(urls["href"])
                        # pdate, pcompany, title, btext
                    f.write("{}\t{}\t{}\t{}\t{}\n".format(news_detail[1], news_detail[4], news_detail[0], news_detail[2],news_detail[3]))  # new style
            except Exception as e:
                print(e)
                continue
        page += 10
    
    
    f.close()

# %%
def excel_make():
    data = pd.read_csv(RESULT_PATH+'contents_text.txt', sep='\t',header=None, error_bad_lines=False)
    data.columns = ['years','company','title','contents','link']
    print(data)
    
    xlsx_outputFileName = '%s-%s-%s  %s시 %s분 %s초 result.xlsx' % (now.year, now.month, now.day, now.hour, now.minute, now.second)
    #xlsx_name = 'result' + '.xlsx'
    data.to_excel(RESULT_PATH+xlsx_outputFileName, encoding='utf-8')

# %%
def main():
    maxpage = input("최대 출력할 페이지수 입력하시오: ") 
    query = input("검색어 입력: ")
    s_date = input("시작날짜 입력(2019.01.01):")  #2019.01.01
    e_date = input("끝날짜 입력(2019.04.28):")   #2019.04.28
    crawler(maxpage,query,s_date,e_date) #검색된 네이버뉴스의 기사내용을 크롤링합니다. 
    
    excel_make() #엑셀로 만들기 
main()
# Out:
# 최대 출력할 페이지수 입력하시오: 5
# 검색어 입력: 코로나온라인쇼핑
# 시작날짜 입력(2019.01.01):2020.09.01
# 끝날짜 입력(2019.04.28):2020.09.10
# 1
# https://search.naver.com/search.naver?where=news&query=코로나온라인쇼핑&sort=0&ds=2020.09.01&de=2020.09.10&nso=so%3Ar%2Cp%3Afrom20200901to20200910%2Ca%3A&start=1
# 11
# https://search.naver.com/search.naver?where=news&query=코로나온라인쇼핑&sort=0&ds=2020.09.01&de=2020.09.10&nso=so%3Ar%2Cp%3Afrom20200901to20200910%2Ca%3A&start=11
# 21
# https://search.naver.com/search.naver?where=news&query=코로나온라인쇼핑&sort=0&ds=2020.09.01&de=2020.09.10&nso=so%3Ar%2Cp%3Afrom20200901to20200910%2Ca%3A&start=21
# 31
# https://search.naver.com/search.naver?where=news&query=코로나온라인쇼핑&sort=0&ds=2020.09.01&de=2020.09.10&nso=so%3Ar%2Cp%3Afrom20200901to20200910%2Ca%3A&start=31
#           years                 company  \
# 0   2020.09.09.                OhmyNews
# 1   2020.09.09.             ZDNet Korea
# 2   2020.09.09.                   헤럴드경제
# 3   2020.09.09.                     뉴스1
# 4   2020.09.10.             ZDNet Korea
# 5   2020.09.09.          financial news
# 6   2020.09.09.                 아시아경제신문
# 7   2020.09.09.                     뉴스1
# 8   2020.09.10.       eTimesinternet Co
# 9   2020.09.09.                     뉴스1
# 10  2020.09.09.          financial news
# 11  2020.09.09.          financial news
# 12  2020.09.10.                  edaily
# 13  2020.09.10.                    조세일보
# 14  2020.09.10.                     뉴스1
# 15  2020.09.10.          financial news
# 16  2020.09.10.                   헤럴드경제
# 17  2020.09.10.                   헤럴드경제
# 18  2020.09.10.                     뉴스1
# 19  2020.09.10.                  edaily
# 20  2020.09.10.          financial news
# 21  2020.09.10.                    조세일보
# 22  2020.09.10.                 아시아경제신문
# 23  2020.09.09.                OhmyNews
# 24  2020.09.09.                     뉴시스
# 25  2020.09.09.          financial news
# 26  2020.09.09.                     뉴스1
# 27  2020.09.10.          financial news
# 28  2020.09.10.                    데일리안
# 29  2020.09.10.                    노컷뉴스
# 30  2020.09.10.                     뉴스1
# 31  2020.09.09.                    연합뉴스
# 32  2020.09.10.                     YTN
# 33  2020.09.10.                    연합뉴스
# 34  2020.09.09.                    조세일보
# 35  2020.09.09.                     뉴스1
# 36  2020.09.09.                    JTBC
# 37  2020.09.10.                    문화일보
# 38  2020.09.09.                    한경닷컴
# 39  2020.09.03.  The Internet Hankyoreh
# 40  2020.09.03.              media KHAN
# 41  2020.09.08.                     더팩트
# 42  2020.09.10.                    국민일보
# 43  2020.09.09.                     뉴시스
# 44  2020.09.09.                 아시아경제신문
# 45  2020.09.09.          financial news
# 46  2020.09.09.                     KBS
# 47  2020.09.09.                     KBS
# 48  2020.09.08.                    연합뉴스
# 49  2020.09.10.                    데일리안
#
#                                      title  \
# 0             코로나19 시대, 친환경 '온라인 녹색매장' 열린다
# 1                 친환경 녹색제품, 이제 온라인에서 구입하세요
# 2                “친환경 제품, 온라인 녹색매장서 구매하세요”
# 3           친환경 녹색제품, 온라인 구매하면 20% 할인권 드려요
# 4                       쿠팡, 소상공인 온라인 판로 지원
# 5               서울시, 소상공인·전통시장 온라인 진출 지원한다
# 6      서울시, 전통시장·소상공인 300개 업체 온라인쇼핑몰 입점 지원
# 7     서울시, '언택트 시대' 소상공인·전통시장 상인 온라인 진출 지원
# 8     홈쇼핑모아 "코로나19 이후 10명 중 8명 온라인으로 장 본다"
# 9         롯데백화점·자갈치시장 '코로나불황 극복' 온라인 판로 확장
# 10                  온라인에서도 “오이소, 보이소, 사이소”
# 11                      '라방'보며 자갈치시장 쇼핑하세요
# 12      현대百그룹, 온라인몰서 '2020 추석 선물세트 판매전' 진행
# 13    현대백화점그룹 온라인몰서 오는 29일까지 '추석 선물세트' 판매전
# 14     현대百, 온라인 추석선물 세트 본격 판매…"총 8000종 선봬"
# 15       현대백화점그룹, 온라인몰서 '2020 추석 선물세트 판매전'
# 16                   실시간 공연 즐기며 쇼핑까지 한 번에…
# 17     라이브 공연보며 쇼핑도 한번에…CJ올리브네트웍스 ‘온택트’ 공략
# 18     현대百, 온라인 추석선물 세트 본격 판매…"총 8000종 선봬"
# 19      현대百그룹, 온라인몰서 '2020 추석 선물세트 판매전' 진행
# 20       현대백화점그룹, 온라인몰서 '2020 추석 선물세트 판매전'
# 21    현대백화점그룹 온라인몰서 오는 29일까지 '추석 선물세트' 판매전
# 22      현대백화점, 온라인몰서 '2020 추석 선물세트 판매전' 진행
# 23              한복, 온라인 상점에서 30% 싼 가격에 사세요
# 24         '한복상점' 온라인 개최…73개 업체, 30% 할인 판매
# 25          예쁜 한복, 온라인 ‘2020 한복상점’에서 구매하세요
# 26         온라인 '2020 한복상점'에서 저렴하게 한복 구매하세요
# 27                   '대한민국 농업박람회' 온라인으로 개최
# 28              온라인 ‘대한민국 농업박람회’ 24~27일 개최
# 29              '코로나 부도' JC페니, 부동산 업체에 팔린다
# 30               사천시, 우체국 온라인쇼핑몰 추석맞이 특별할인
# 31             대구시 사회적경제기업 돕는 온라인 홈쇼핑마켓 개설
# 32    코로나인데..추석연휴 귀향할까, 말까 시민들 생각은? [반찬토론]
# 33              온라인몰, 지역 농가·소상공인 판로 지원 나선다
# 34         매일유업,   제휴 온라인 쇼핑몰에서  '추석선물' 선봬
# 35        '코로나 극복 프로젝트' 영동군, 2020 링링동 첫 진행
# 36           코로나 '무인판매' 노인들 소외감…주문 하나에 13분
# 37                      NS홈쇼핑, 추석대전 이벤트 진행
# 38     삼성의 '비대면 추석나눔'…온라인몰 만들어 자매마을 특산품 판매
# 39            7월 온라인쇼핑 역대 최대…식품·음식배달 주문 급증
# 40           코로나19로 온라인쇼핑 역대 최대 ‘배달 음식’ 급증
# 41    코로나19에 태풍까지…온라인쇼핑 '당일배송' 거래액 120% 증가
# 42           경북도, ‘코로나 면역 효자’ 김치산업 제대로 키운다
# 43   [영동소식]코로나19 장기화 독감무료접종 대상 50~61세 확대 등
# 44           롯데백화점, 코로나19 반영한 이색 추석 선물 선보여
# 45      코로나發 내수침체 엉뚱한 불똥?… 유통산업에 규제법안 꺼낸 與
# 46              명절 준비도 ‘비대면’으로…“온라인·배송 확대”
# 47              명절 준비도 ‘비대면’으로…“온라인·배송 확대”
# 48             횡성군 중소기업 쇼핑몰 오픈…코로나19 극복 지원
# 49  TV 호조-스마트폰 회복 기대 속 DP 순풍에 코로나·화웨이 변수되나
#
#                                              contents  \
# 0   소비자 선호 녹색제품 기획전 개최, 최대 20% 할인권 지급[김병기 기자] ▲  인...
# 1   환경부-환경산업기술원, 12월31일까지 온라인 녹색매장 운영(지디넷코리아=박영민  ...
# 2   환경산업기술원 녹색제품 기획전환경부 산하 한국환경산업기술원(원장 유제철·사진)은 9...
# 3   온라인 녹색매장 연말까지 시범운영 (세종=뉴스1) 한종수 기자 = 환경부와 한국환경...
# 4   농림축산식품부, 한국농수산식품유통공사와 농공상기업 돕는 기획전 진행(지디넷코리아=안...
# 5   /사진=뉴스1[파이낸셜뉴스] 서울시는 온라인쇼핑 운영 경험이 많지 않은 소상공인과 ...
# 6   쿠팡·11번가 등에 전용관 개설 … 판매수수료 2~5% 인하 추진온라인장보기 전통시...
# 7   소상공인 300곳 쿠팡 등 입점 지원…판매수수료 2~5%p 인하전통시장 온라인시장 ...
# 8   모바일 홈쇼핑 포털 애플리케이션(앱) 홈쇼핑모아를 운영하는 버즈니(공동대표 남상협,...
# 9   광복점, 자갈치시장 직송관 만들어 전통시장 온라인 판매 도와롯데백화점 광복점 부산 ...
# 10  【파이낸셜뉴스 부산=노동균 기자】 부산지역 최대 수산물 시장인 자갈치 시장과 롯데백...
# 11  롯데百 광복점 '상생안' 눈길전통시장 온라인 판로 확장나서'백라이브 채널팀' 부산에...
# 12  더현대닷컴·현대식품관 투홈·현대H몰에서 실시총 8000여 품목 선봬…구매금액 10%...
# 13  ◆…사진=현대백화점그룹 제공현대백화점이 온라인몰에서 본격적인 추석 선물세트 판매에 ...
# 14  더현대닷컴, 현대H몰, 투홈 동시 판매(현대백화점그룹 제공)© 뉴스1(서울=뉴스1)...
# 15  [파이낸셜뉴스] 현대백화점이 온라인몰을 통해 본격적인 추석 선물세트 판매에 돌입한다...
# 16  CJ올리브네트웍스 ‘라이브 라떼’라이브공연·커머스 플랫폼 결합CJ올리브네트웍스가 실...
# 17  -라이브 공연·커머스 결합 ‘라이브 라떼’ 출시-K-팝 공연보면서 아이돌 굿즈 판매...
# 18  더현대닷컴, 현대H몰, 투홈 동시 판매(현대백화점그룹 제공)© 뉴스1(서울=뉴스1)...
# 19  더현대닷컴·현대식품관 투홈·현대H몰에서 실시총 8000여 품목 선봬…구매금액 10%...
# 20  [파이낸셜뉴스] 현대백화점이 온라인몰을 통해 본격적인 추석 선물세트 판매에 돌입한다...
# 21  ◆…사진=현대백화점그룹 제공현대백화점이 온라인몰에서 본격적인 추석 선물세트 판매에 ...
# 22  더현대닷컴, 현대식품관 투홈, 현대H몰에서 총 8000여 품목 선보여구매금액의 10...
# 23  10일부터 네이버 쇼핑라이브, 유튜브 ‘한복상점’에서 실시간 판매 방송[김병기 기자...
# 24  '네이버 쇼핑라이브'-유튜브 채널 '한복상점'10일부터 13일까지 실시간 방송[서울...
# 25  한복상점 [파이낸셜뉴스] 문화체육관광부는 한국공예·디자인문화진흥원, 한복진흥센터와 ...
# 26  13일까지 네이버 쇼핑, 유튜브 '한복상점'에서 실시간 방송 판매12월31까지 공식...
# 27  미래학자 제이슨 셰커 초대 '세계의 변화와 농업의 미래 전략' 대담  [파이낸셜뉴스...
# 28  ‘농업의 현재와 미래’ 주제, 종합박람회로 진행전문가 영상대담·최신 농업혁신기술 영...
# 29  [CBS노컷뉴스 이재웅 기자]뉴욕의 JC페니 매장. (사진=연합뉴스/자료사진) 코로...
# 30  우체국 온라인 쇼핑몰 '사천기획전' 홍보 포스터. © 뉴스1(경남=뉴스1) 한송학 ...
# 31  B대면 B급장터 방송 장면[대구시 제공. 재판매 및 DB 금지]    (대구=연합뉴...
# 32  YTN라디오(FM 94.5) [YTN 뉴스FM 슬기로운 라디오생활]□ 방송일시 : ...
# 33  GS프레시몰 지역 농가 지원[GS프레시몰 제공. 재판매 및 DB 금지]    (서울...
# 34  네이버 브랜드스토어,카카오톡,쿠팡 등 온라인몰 이용'셀렉스 코어 프로틴’& 상하농원...
# 35  오는 12월 말까지 농특산물 판매·문화행사영동군이 주최하는 '2020 (셀)링·(힐...
# 36  동영상 뉴스       [앵커]무인 기계로 주문하고, 온라인으로 쇼핑하고. 코로나1...
# 37  구매 조건 맞추면 10만 원 적립…랜던 적립금 당첨 이벤트도NS홈쇼핑은 추석 명절을...
# 38  삼성 직원 20만명 겨냥한 '이벤트 몰' 다음달 중순까지 운영협력업체 물품대금 1조...
# 39  농축수산물 72.8%↑ 음식서비스 66.3%↑지난 1일 오후 서울 노원구 롯데마트 ...
# 40  [경향신문] 2일 오전 서울 중구 북창동순두부에서 관계자가 배달을 하고 있다. 연합...
# 41  국내 코로나19 사태가 지속되는 가운데 악천후까지 겹치면서 온라인으로 생필품을 구매...
# 42  면역력 관심 반영 수출·내수 급증…  2024년까지 1283억 투입 집중육성경북도는...
# 43  [영동=뉴시스]김재광 기자 = 충북 영동군이 신종 코로나바이러스 감염증(코로나19)...
# 44  롯데백화점에서 고객들이 주방 상품을 둘러보고 있다. (사진=롯데백화점 제공)[아시아...
# 45  '유통산업발전법개정안'6건 발의의무 휴업·영업 제한 고강도 추진온라인 반사익 등 실...
# 46  [KBS 대구] [앵커] 코로나19가 다시 확산하고 있는 가운데 추석이 한 달 앞으...
# 47  [KBS 대구] [앵커] 코로나19가 다시 확산하고 있는 가운데 추석이 한 달 앞으...
# 48  횡성군청 청사[연합뉴스 자료사진]    (횡성=연합뉴스) 김영인 기자 = 강원 횡성...
# 49  삼성-LGD, 하반기 나란히 실적 개선 기대감 커져...전방시장 효과코로나19 장기...
#
#                                                  link
# 0   https://news.naver.com/main/read.nhn?mode=LSD&...
# 1   https://news.naver.com/main/read.nhn?mode=LSD&...
# 2   https://news.naver.com/main/read.nhn?mode=LSD&...
# 3   https://news.naver.com/main/read.nhn?mode=LSD&...
# 4   https://news.naver.com/main/read.nhn?mode=LSD&...
# 5   https://news.naver.com/main/read.nhn?mode=LSD&...
# 6   https://news.naver.com/main/read.nhn?mode=LSD&...
# 7   https://news.naver.com/main/read.nhn?mode=LSD&...
# 8   https://news.naver.com/main/read.nhn?mode=LSD&...
# 9   https://news.naver.com/main/read.nhn?mode=LSD&...
# 10  https://news.naver.com/main/read.nhn?mode=LSD&...
# 11  https://news.naver.com/main/read.nhn?mode=LSD&...
# 12  https://news.naver.com/main/read.nhn?mode=LSD&...
# 13  https://news.naver.com/main/read.nhn?mode=LSD&...
# 14  https://news.naver.com/main/read.nhn?mode=LSD&...
# 15  https://news.naver.com/main/read.nhn?mode=LSD&...
# 16  https://news.naver.com/main/read.nhn?mode=LSD&...
# 17  https://news.naver.com/main/read.nhn?mode=LSD&...
# 18  https://news.naver.com/main/read.nhn?mode=LSD&...
# 19  https://news.naver.com/main/read.nhn?mode=LSD&...
# 20  https://news.naver.com/main/read.nhn?mode=LSD&...
# 21  https://news.naver.com/main/read.nhn?mode=LSD&...
# 22  https://news.naver.com/main/read.nhn?mode=LSD&...
# 23  https://news.naver.com/main/read.nhn?mode=LSD&...
# 24  https://news.naver.com/main/read.nhn?mode=LSD&...
# 25  https://news.naver.com/main/read.nhn?mode=LSD&...
# 26  https://news.naver.com/main/read.nhn?mode=LSD&...
# 27  https://news.naver.com/main/read.nhn?mode=LSD&...
# 28  https://news.naver.com/main/read.nhn?mode=LSD&...
# 29  https://news.naver.com/main/read.nhn?mode=LSD&...
# 30  https://news.naver.com/main/read.nhn?mode=LSD&...
# 31  https://news.naver.com/main/read.nhn?mode=LSD&...
# 32  https://news.naver.com/main/read.nhn?mode=LSD&...
# 33  https://news.naver.com/main/read.nhn?mode=LSD&...
# 34  https://news.naver.com/main/read.nhn?mode=LSD&...
# 35  https://news.naver.com/main/read.nhn?mode=LSD&...
# 36  https://news.naver.com/main/read.nhn?mode=LSD&...
# 37  https://news.naver.com/main/read.nhn?mode=LSD&...
# 38  https://news.naver.com/main/read.nhn?mode=LSD&...
# 39  https://news.naver.com/main/read.nhn?mode=LSD&...
# 40  https://news.naver.com/main/read.nhn?mode=LSD&...
# 41  https://news.naver.com/main/read.nhn?mode=LSD&...
# 42  https://news.naver.com/main/read.nhn?mode=LSD&...
# 43  https://news.naver.com/main/read.nhn?mode=LSD&...
# 44  https://news.naver.com/main/read.nhn?mode=LSD&...
# 45  https://news.naver.com/main/read.nhn?mode=LSD&...
# 46  https://news.naver.com/main/read.nhn?mode=LSD&...
# 47  https://news.naver.com/main/read.nhn?mode=LSD&...
# 48  https://news.naver.com/main/read.nhn?mode=LSD&...
# 49  https://news.naver.com/main/read.nhn?mode=LSD&...
